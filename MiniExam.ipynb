# %% [markdown]
# <a href="https://colab.research.google.com/github/Jennapa-colab/DWDM21/blob/main/MiniExam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### ข้อสอบ
#
# จาก data ```flights.csv``` และ ```airports.csv``` ใน https://drive.google.com/drive/folders/1EFo1_uQgWkRiXjezL0T4YwteYrsqU5MV?usp=sharing
# 0. หารัฐที่มีจำนวนเครื่องบินขาเข้ามากที่สุดและน้อยที่สุด
# 1. หารัฐที่มีจำนวนเครื่องบินขาออกมากที่สุดและน้อยที่สุด
# 2. วาด Histogram แสดงจำนวนเครื่องบินขาออกของแต่ละวันในสัปดาห์
# 3. สายการบินไหนมีเที่ยวบินมากที่สุดและน้อยที่สุด
# 4. สายการบินอะไรมีความล่าช้ามากที่สุดและน้อยที่สุด
# 5. ช่วงเช้าหรือช่วงบ่ายมีเครื่องบินขาเข้ามากกว่ากัน
#
# ให้นักศึกษาทำข้อสอบ 2 ข้อจากที่แสดงข้างบนโดยกรอกรหัสนักศึกษาลงใน function ```gen_exams()``` แล้ว run เพื่อให้ได้ข้อสอบที่นักศึกษาต้องทำ 2 ข้อ (ข้อละ 3 คะแนน)
# และให้นักศึกษาคิดโจทย์เองอีก 1 ข้อ (4 คะแนน)

# %%
import pandas as pd

# %%
from google.colab import drive 
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os

# %%
flights = pd.read_csv('/content/drive/MyDrive/DWDM2021_DATA/flights.csv')
flights
# Out:
#          วันในเดือน  วันในสัปดาห์  ... ความล่าช้าขาออก  ความล่าช้าขาเข้า
# 0                19             5  ...              -3                 1
# 1                19             5  ...               0                -8
# 2                19             5  ...              -4               -15
# 3                19             5  ...              28                24
# 4                19             5  ...              -6               -11
# ...             ...           ...  ...             ...               ...
# 2702213          19             6  ...               1                -3
# 2702214          19             6  ...              -2                -3
# 2702215          19             6  ...              18                 9
# 2702216          19             6  ...              10                 7
# 2702217          19             6  ...               0               -13
#
# [2702218 rows x 7 columns]

# %%
airports = pd.read_csv('/content/drive/MyDrive/DWDM2021_DATA/airports.csv')
airports
# Out:
#      รหัสสนามบิน         เมือง รัฐ                          ชื่อสนามบิน
# 0          10165   Adak Island  AK                                 Adak
# 1          10299     Anchorage  AK  Ted Stevens Anchorage International
# 2          10304         Aniak  AK                        Aniak Airport
# 3          10754        Barrow  AK      Wiley Post/Will Rogers Memorial
# 4          10551        Bethel  AK                       Bethel Airport
# ..           ...           ...  ..                                  ...
# 360        11233      Cheyenne  WY  Cheyenne Regional/Jerry Olson Field
# 361        11097          Cody  WY                 Yellowstone Regional
# 362        11865      Gillette  WY             Gillette Campbell County
# 363        12441       Jackson  WY                         Jackson Hole
# 364        14543  Rock Springs  WY       Rock Springs Sweetwater County
#
# [365 rows x 4 columns]

# %%
def gen_exams(ID):
    import math
    a = int(ID[-1])%6
    b = int(ID[-1])%3
    print(f'รหัสนักศึกษา {6230205153} ทำข้อ {a} และ {b if a != b else 5-b}')

# %% [markdown]
# ตัวอย่างการ run

# %%
gen_exams('6230205153')
# Out:
# รหัสนักศึกษา 6230205153 ทำข้อ 3 และ 0

# %%
merged_table = flights.merge(airports,how='left',left_on='รหัสสนามบินต้นทาง',right_on='รหัสสนามบิน')
merged_table
# Out:
#          วันในเดือน  ...                                 ชื่อสนามบิน
# 0                19  ...                  Detroit Metro Wayne County
# 1                19  ...                Salt Lake City International
# 2                19  ...                      Portland International
# 3                19  ...             Lambert-St. Louis International
# 4                19  ...  Cincinnati/Northern Kentucky International
# ...             ...  ...                                         ...
# 2702213          19  ...                       Orlando International
# 2702214          19  ...    Hartsfield-Jackson Atlanta International
# 2702215          19  ...           Albuquerque International Sunport
# 2702216          19  ...    Hartsfield-Jackson Atlanta International
# 2702217          19  ...    Hartsfield-Jackson Atlanta International
#
# [2702218 rows x 11 columns]

# %%
flights.isnull().any() 
#หาค่า missing
# Out:
# วันในเดือน            False
# วันในสัปดาห์          False
# สายการบิน             False
# รหัสสนามบินต้นทาง     False
# รหัสสนามบินปลายทาง    False
# ความล่าช้าขาออก       False
# ความล่าช้าขาเข้า      False
# dtype: bool

# %%
airports = pd.read_csv('/content/drive/MyDrive/DWDM2021_DATA/airports.csv')
airports
# Out:
#      รหัสสนามบิน         เมือง รัฐ                          ชื่อสนามบิน
# 0          10165   Adak Island  AK                                 Adak
# 1          10299     Anchorage  AK  Ted Stevens Anchorage International
# 2          10304         Aniak  AK                        Aniak Airport
# 3          10754        Barrow  AK      Wiley Post/Will Rogers Memorial
# 4          10551        Bethel  AK                       Bethel Airport
# ..           ...           ...  ..                                  ...
# 360        11233      Cheyenne  WY  Cheyenne Regional/Jerry Olson Field
# 361        11097          Cody  WY                 Yellowstone Regional
# 362        11865      Gillette  WY             Gillette Campbell County
# 363        12441       Jackson  WY                         Jackson Hole
# 364        14543  Rock Springs  WY       Rock Springs Sweetwater County
#
# [365 rows x 4 columns]

# %%
airports.isnull().any() 
#หาค่า missing
# Out:
# รหัสสนามบิน    False
# เมือง          False
# รัฐ            False
# ชื่อสนามบิน    False
# dtype: bool

# %% [markdown]
# ##ข้อ 3 สายการบินไหนมีเที่ยวบินมากที่สุดและน้อยที่สุด

# %%
Max = merged_table.sort_values(by=['สายการบิน'],ascending = False)
Max.iloc[:1,[2,3]]
# Out:
#         สายการบิน  รหัสสนามบินต้นทาง
# 1087306        YV              12264

# %%
Min = merged_table.sort_values(by=['สายการบิน'],ascending=True)
Min.iloc[:1,[2,3]]
# Out:
#         สายการบิน  รหัสสนามบินต้นทาง
# 1625949        9E              11433

# %%
MaxMin = flights.groupby('สายการบิน')[['วันในเดือน']].count()
MaxMin
# Out:
#            วันในเดือน
# สายการบิน
# 9E              80031
# AA             289855
# AS              68555
# B6             121906
# DL             381657
# EV             157928
# F9              35738
# FL              92702
# HA              17432
# MQ             113212
# OO             160164
# UA             286418
# US             233321
# VX              34739
# WN             575739
# YV              52821

# %%
MaxMin.reset_index(inplace=True)
MaxMin
# Out:
#    สายการบิน  วันในเดือน
# 0         9E       80031
# 1         AA      289855
# 2         AS       68555
# 3         B6      121906
# 4         DL      381657
# 5         EV      157928
# 6         F9       35738
# 7         FL       92702
# 8         HA       17432
# 9         MQ      113212
# 10        OO      160164
# 11        UA      286418
# 12        US      233321
# 13        VX       34739
# 14        WN      575739
# 15        YV       52821

# %%
MaxMin = MaxMin.sort_values(by=['วันในเดือน'],ascending=False)
MaxMin
# Out:
#    สายการบิน  วันในเดือน
# 14        WN      575739
# 4         DL      381657
# 1         AA      289855
# 11        UA      286418
# 12        US      233321
# 10        OO      160164
# 5         EV      157928
# 3         B6      121906
# 9         MQ      113212
# 7         FL       92702
# 0         9E       80031
# 2         AS       68555
# 15        YV       52821
# 6         F9       35738
# 13        VX       34739
# 8         HA       17432

# %% [markdown]
# ##สายการบินมีเที่ยวบินมากที่สุด

# %%
Max = MaxMin.sort_values(by=['วันในเดือน'],ascending=False)
Max.iloc[0,:]
# Out:
# สายการบิน         WN
# วันในเดือน    575739
# Name: 14, dtype: object

# %% [markdown]
# ##สายการบินที่มีเที่ยวบินน้อยที่สุด

# %%
Min= MaxMin.sort_values(by=['วันในเดือน'],ascending=False)
Min.iloc[-1,:]
# Out:
# สายการบิน        HA
# วันในเดือน    17432
# Name: 8, dtype: object

# %% [markdown]
# ##ตอบคือ
#
# *สายการบินมีเที่ยวบิน คือ สายการบิน WN มีจำนวนเที่ยวบิน 575739 เที่ยวบิน*
#
# *สายการบินมีเที่ยวบิน คือ สายการบิน HA มีจำนวนเที่ยวบิน 17432 เที่ยวบิน*

# %% [markdown]
# ##ข้อ 0 หารัฐที่มีจำนวนเครื่องบินขาเข้ามากที่สุดและน้อยที่สุด

# %%
merged_table = flights.merge(airports,how='left',left_on='รหัสสนามบินปลายทาง',right_on='รหัสสนามบิน') 
#ตารางซ้ายของตารางหลัก ผูกกับ right_on id
merged_table
# Out:
#          วันในเดือน  ...                                ชื่อสนามบิน
# 0                19  ...                        Miami International
# 1                19  ...              John F. Kennedy International
# 2                19  ...               Salt Lake City International
# 3                19  ...                 Detroit Metro Wayne County
# 4                19  ...                  Los Angeles International
# ...             ...  ...                                        ...
# 2702213          19  ...               Salt Lake City International
# 2702214          19  ...  Louis Armstrong New Orleans International
# 2702215          19  ...   Hartsfield-Jackson Atlanta International
# 2702216          19  ...                      Memphis International
# 2702217          19  ...          Minneapolis-St Paul International
#
# [2702218 rows x 11 columns]

# %%
merged_table.groupby('รัฐ').count()
# Out:
#      วันในเดือน  วันในสัปดาห์  สายการบิน  ...  รหัสสนามบิน   เมือง  ชื่อสนามบิน
# รัฐ                                       ...
# AK         7700          7700       7700  ...         7700    7700         7700
# AZ       100710        100710     100710  ...       100710  100710       100710
# CA       380046        380046     380046  ...       380046  380046       380046
# CO        97259         97259      97259  ...        97259   97259        97259
# CT        13042         13042      13042  ...        13042   13042        13042
# DC        80536         80536      80536  ...        80536   80536        80536
# FL       208139        208139     208139  ...       208139  208139       208139
# GA       148563        148563     148563  ...       148563  148563       148563
# HI        28395         28395      28395  ...        28395   28395        28395
# IL       176939        176939     176939  ...       176939  176939       176939
# ...

# %%
merged_table.groupby('รัฐ').count().sort_values(by=['รหัสสนามบินปลายทาง'],ascending=False)
# Out:
#      วันในเดือน  วันในสัปดาห์  สายการบิน  ...  รหัสสนามบิน   เมือง  ชื่อสนามบิน
# รัฐ                                       ...
# CA       380429        380429     380429  ...       380429  380429       380429
# TX       275328        275328     275328  ...       275328  275328       275328
# FL       208291        208291     208291  ...       208291  208291       208291
# IL       176857        176857     176857  ...       176857  176857       176857
# GA       148524        148524     148524  ...       148524  148524       148524
# NY       132522        132522     132522  ...       132522  132522       132522
# NC       104839        104839     104839  ...       104839  104839       104839
# AZ       100824        100824     100824  ...       100824  100824       100824
# CO        96919         96919      96919  ...        96919   96919        96919
# NV        88179         88179      88179  ...        88179   88179        88179
# ...

# %%
state= merged_table.groupby('รัฐ').count().sort_values(by=['รหัสสนามบินปลายทาง'],ascending=False)
state
# Out:
#      วันในเดือน  วันในสัปดาห์  สายการบิน  ...  รหัสสนามบิน   เมือง  ชื่อสนามบิน
# รัฐ                                       ...
# CA       380429        380429     380429  ...       380429  380429       380429
# TX       275328        275328     275328  ...       275328  275328       275328
# FL       208291        208291     208291  ...       208291  208291       208291
# IL       176857        176857     176857  ...       176857  176857       176857
# GA       148524        148524     148524  ...       148524  148524       148524
# NY       132522        132522     132522  ...       132522  132522       132522
# NC       104839        104839     104839  ...       104839  104839       104839
# AZ       100824        100824     100824  ...       100824  100824       100824
# CO        96919         96919      96919  ...        96919   96919        96919
# NV        88179         88179      88179  ...        88179   88179        88179
# ...

# %% [markdown]
# ##รัฐที่มีจำนวนเครื่องบินขาเข้ามากที่สุด

# %%
Max = state1.iloc[:1,5:6]
Max
# Out:
#      ความล่าช้าขาออก
# รัฐ
# CA            380429

# %% [markdown]
# ##รัฐที่มีจำนวนเครื่องบินขาเข้าน้อยที่สุด

# %%
Min = state1.iloc[-1:,5:6] 
Min
# Out:
#      ความล่าช้าขาออก
# รัฐ
# AK              7711

# %% [markdown]
# ##คำตอบ
# *รัฐที่มีจำนวนเครื่องบินขาเข้ามากที่สุดคือรัฐ CA มีจำนวนเครื่องบินขาเข้าทั้งหมด 380,429*
#
#
# รัฐที่มีจำนวนเครื่องบินขาเข้าน้อยที่สุดคือ AK และ มีจำนวนเครื่องบินขาเข้าทั้งหมด 7,711

# %% [markdown]
# ##โจทย์คิดเอง รัฐใดที่มีค่าเฉลี่ยของ 'ความล่าช้าขาออก' สูงที่สุด 20 อันดับแรก

# %%
pp = merged_table.groupby('รัฐ').mean().sort_values(by=['ความล่าช้าขาออก'],ascending=False)
pp.iloc[:20,[4]]
# Out:
#      ความล่าช้าขาออก
# รัฐ
# NJ         17.528695
# NY         13.748630
# IL         13.287820
# OK         13.260970
# VA         12.711593
# KY         12.539698
# RI         12.215036
# CT         12.193482
# NE         11.912252
# NM         11.620743
# MO         11.522888
# CA         11.467362
# PR         11.300210
# CO         11.284588
# WI         11.267555
# MD         11.001006
# OH         10.905142
# IN         10.762953
# LA         10.543094
# PA         10.397307
